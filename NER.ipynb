# %%
import pandas as pd

# %%
df = pd.read_csv("data/ner_dataset_10k.csv")

# %% [markdown]
# # NER (Rule-based for Finance Posts)

# %% [markdown]
# ## Rule-based NER description
#
# We'll implement simple rules:
# - Cashtags: `$AAPL`, `$TSLA` using regex
# - Company lookup: exact string match against a company list
# - Person lookup: exact string match against a list of known people

# %%
import re

# %%
# update these lists if you want more/company names
companies = {
    "AAPL": "Apple Inc",
    "MSFT": "Microsoft Corporation",
    "GOOG": "Alphabet Inc",
    "AMZN": "Amazon.com, Inc",
    "TSLA": "Tesla, Inc",
    "NVDA": "NVIDIA Corporation",
    "JPM": "JPMorgan Chase & Co.",
    "BAC": "Bank of America Corporation",
    "WMT": "Walmart Inc",
    "META": "Meta Platforms, Inc"
}
people = [
    "Tim Cook","Satya Nadella","Sundar Pichai","Elon Musk",
    "Jensen Huang","Jamie Dimon","Warren Buffett","Mark Zuckerberg",
    "Andy Jassy","Brian Moynihan"
]

# %%
def extract_entities(text):
    entities = {'CASHTAG': [], 'COMPANY': [], 'PERSON': []}
    if not isinstance(text, str):
        return entities
    # cashtags: $ followed by 1-5 uppercase letters/numbers
    entities['CASHTAG'] = re.findall(r"\$[A-Z0-9]{1,5}", text)
    # company exact match (case-sensitive or insensitive? use case-insensitive)
    for comp in companies.values():
        if comp.lower() in text.lower():
            entities['COMPANY'].append(comp)
    # persons
    for p in people:
        if p.lower() in text.lower():
            entities['PERSON'].append(p)
    return entities

# %%
# test on a few samples
sample_texts = df['text'].sample(10, random_state=3).tolist()
for t in sample_texts:
    print("TEXT:", t)
    print("EXTRACTED:", extract_entities(t))
    print("---")
# Out:
# TEXT: Satya Nadella of Bank of America Corporation commented on strategy. $BAC reacts to the news. Analysts: hold.
# EXTRACTED: {'CASHTAG': ['$BAC'], 'COMPANY': ['Bank of America Corporation'], 'PERSON': ['Satya Nadella']}
# ---
# TEXT: Warren Buffett of Meta Platforms, Inc commented on strategy. $META reacts to the news. Analysts: upgrade.
# EXTRACTED: {'CASHTAG': ['$META'], 'COMPANY': ['Meta Platforms, Inc'], 'PERSON': ['Warren Buffett']}
# ---
# TEXT: Mark Zuckerberg of Walmart Inc commented on strategy. $WMT reacts to the news. Analysts: downgrade.
# EXTRACTED: {'CASHTAG': ['$WMT'], 'COMPANY': ['Walmart Inc'], 'PERSON': ['Mark Zuckerberg']}
# ---
# TEXT: Satya Nadella of Bank of America Corporation commented on strategy. $BAC reacts to the news. Analysts: upgrade.
# EXTRACTED: {'CASHTAG': ['$BAC'], 'COMPANY': ['Bank of America Corporation'], 'PERSON': ['Satya Nadella']}
# ---
# TEXT: Satya Nadella of JPMorgan Chase & Co. commented on strategy. $JPM reacts to the news. Analysts: upgrade.
# EXTRACTED: {'CASHTAG': ['$JPM'], 'COMPANY': ['JPMorgan Chase & Co.'], 'PERSON': ['Satya Nadella']}
# ---
# TEXT: Jamie Dimon of Alphabet Inc commented on strategy. $GOOG reacts to the news. Analysts: hold.
# EXTRACTED: {'CASHTAG': ['$GOOG'], 'COMPANY': ['Alphabet Inc'], 'PERSON': ['Jamie Dimon']}
# ---
# TEXT: Sundar Pichai of Walmart Inc commented on strategy. $WMT reacts to the news. Analysts: upgrade.
# EXTRACTED: {'CASHTAG': ['$WMT'], 'COMPANY': ['Walmart Inc'], 'PERSON': ['Sundar Pichai']}
# ---
# TEXT: Warren Buffett of Alphabet Inc commented on strategy. $GOOG reacts to the news. Analysts: downgrade.
# EXTRACTED: {'CASHTAG': ['$GOOG'], 'COMPANY': ['Alphabet Inc'], 'PERSON': ['Warren Buffett']}
# ---
# TEXT: Mark Zuckerberg of Walmart Inc commented on strategy. $WMT reacts to the news. Analysts: upgrade.
# EXTRACTED: {'CASHTAG': ['$WMT'], 'COMPANY': ['Walmart Inc'], 'PERSON': ['Mark Zuckerberg']}
# ---
# TEXT: Jensen Huang of NVIDIA Corporation commented on strategy. $NVDA reacts to the news. Analysts: hold.
# EXTRACTED: {'CASHTAG': ['$NVDA'], 'COMPANY': ['NVIDIA Corporation'], 'PERSON': ['Jensen Huang']}
# ---

# %%
# apply to first 100 rows (fast demonstration)
df_sample = df.head(100).copy()
df_sample['entities'] = df_sample['text'].apply(extract_entities)
df_sample[['text','entities']].head(10)
# Out:
#                                                 text  \
# 0  Elon Musk of Bank of America Corporation comme...
# 1  Jensen Huang of Tesla, Inc commented on strate...
# 2  Jensen Huang of Apple Inc commented on strateg...
# 3  Sundar Pichai of NVIDIA Corporation commented ...
# 4  Elon Musk of Alphabet Inc commented on strateg...
# 5  Sundar Pichai of Meta Platforms, Inc commented...
# 6  Warren Buffett of JPMorgan Chase & Co. comment...
# 7  Andy Jassy of JPMorgan Chase & Co. commented o...
# 8  Andy Jassy of Alphabet Inc commented on strate...
# 9  Brian Moynihan of Alphabet Inc commented on st...
#
#                                             entities
# 0  {'CASHTAG': ['$BAC'], 'COMPANY': ['Bank of Ame...
# 1  {'CASHTAG': ['$TSLA'], 'COMPANY': ['Tesla, Inc...
# 2  {'CASHTAG': ['$AAPL'], 'COMPANY': ['Apple Inc'...
# 3  {'CASHTAG': ['$NVDA'], 'COMPANY': ['NVIDIA Cor...
# 4  {'CASHTAG': ['$GOOG'], 'COMPANY': ['Alphabet I...
# 5  {'CASHTAG': ['$META'], 'COMPANY': ['Meta Platf...
# 6  {'CASHTAG': ['$JPM'], 'COMPANY': ['JPMorgan Ch...
# 7  {'CASHTAG': ['$JPM'], 'COMPANY': ['JPMorgan Ch...
# 8  {'CASHTAG': ['$GOOG'], 'COMPANY': ['Alphabet I...
# 9  {'CASHTAG': ['$GOOG'], 'COMPANY': ['Alphabet I...

# %% [markdown]
# # Pre-trained Statistical NER (using spaCy)

# %%
! pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.11.1)
# Requirement already satisfied: jinja2 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (72.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chetan\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.6/12.8 MB 8.4 MB/s eta 0:00:02
#      -------- ------------------------------- 2.6/12.8 MB 6.3 MB/s eta 0:00:02
#      --------- ------------------------------ 2.9/12.8 MB 5.6 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 3.8 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.4/12.8 MB 3.2 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.1 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.2/12.8 MB 3.5 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 4.0 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.8 MB 4.3 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.8 MB 4.7 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 4.9 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 5.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 4.9 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import spacy

# %%
# 1. Load the spaCy model
# This object contains all the statistical knowledge
nlp = spacy.load("en_core_web_sm")

# %%
# 3. Define a new extraction function using spaCy
def extract_entities_spacy(text):
        # Process the text with the nlp object
        doc = nlp(text)
        
        # Create a dictionary to hold entities
        entities = {}
        for ent in doc.ents:
            label = ent.label_
            text = ent.text
            
            if label not in entities:
                entities[label] = []
            
            # Add the entity text if it's not already listed
            if text not in entities[label]:
                entities[label].append(text)
                
        return entities

# %%
 # 4. Apply the function to a sample
print("Applying spaCy NER to the first 10 rows...")
df_sample = df.head(10).copy()
df_sample['spacy_entities'] = df_sample['text'].apply(extract_entities_spacy)
# Out:
# Applying spaCy NER to the first 10 rows...

# %%
 # 5. Show the comparison
print("\n--- Comparison of Ground Truth vs. spaCy NER Output ---")
print(df_sample[['text', 'mentioned_person', 'company', 'spacy_entities']])
# Out:
# --- Comparison of Ground Truth vs. spaCy NER Output ---
#                                                 text mentioned_person  \
# 0  Elon Musk of Bank of America Corporation comme...        Elon Musk
# 1  Jensen Huang of Tesla, Inc commented on strate...     Jensen Huang
# 2  Jensen Huang of Apple Inc commented on strateg...     Jensen Huang
# 3  Sundar Pichai of NVIDIA Corporation commented ...    Sundar Pichai
# 4  Elon Musk of Alphabet Inc commented on strateg...        Elon Musk
# 5  Sundar Pichai of Meta Platforms, Inc commented...    Sundar Pichai
# 6  Warren Buffett of JPMorgan Chase & Co. comment...   Warren Buffett
# 7  Andy Jassy of JPMorgan Chase & Co. commented o...       Andy Jassy
# 8  Andy Jassy of Alphabet Inc commented on strate...       Andy Jassy
# 9  Brian Moynihan of Alphabet Inc commented on st...   Brian Moynihan
#
#                        company  \
# 0  Bank of America Corporation
# 1                   Tesla, Inc
# 2                    Apple Inc
# 3           NVIDIA Corporation
# 4                 Alphabet Inc
# 5          Meta Platforms, Inc
# 6         JPMorgan Chase & Co.
# 7         JPMorgan Chase & Co.
# 8                 Alphabet Inc
# 9                 Alphabet Inc
#
#                                       spacy_entities
# 0    {'ORG': ['Bank of America Corporation', 'BAC']}
# 1  {'PERSON': ['Jensen Huang', 'TSLA'], 'NORP': [...
# 2  {'PERSON': ['Jensen Huang', 'AAPL'], 'ORG': ['...
# 3           {'PERSON': ['Sundar Pichai of', 'NVDA']}
# 4      {'ORG': ['Alphabet Inc'], 'PERSON': ['GOOG']}
# 5  {'ORG': ['Sundar Pichai of', 'Meta Platforms, ...
# 6  {'PERSON': ['Warren Buffett'], 'ORG': ['JPMorg...
# 7  {'PERSON': ['Andy Jassy'], 'ORG': ['JPMorgan C...
# 8  {'PERSON': ['Andy Jassy', 'GOOG'], 'ORG': ['Al...
# 9  {'PERSON': ['Brian Moynihan', 'GOOG'], 'ORG': ...
